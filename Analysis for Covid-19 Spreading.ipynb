# %% [markdown]
# ## Covid-19 World Spreading analysis

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel('Covid-19_.xlsx')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                      Country/Region  Confirmed Country Abbr 2 Country Abbr 3
# 0                        Azerbaijan      38293             AZ            AZE
# 1                        St. Martin        256             SX            SXM
# 2                       Afghanistan      38706            AF             AFG
# 3                           Albania       5717            AL             ALB
# 4                           Algeria      30406            DZ             DZA
# 5                           Andorra       1444            AD             AND
# 6                            Angola       1221            AO             AGO
# 7               Antigua and Barbuda         88            AN             ATG
# 8                         Argentina     202616            AR             ARG
# 9                           Armenia      35631            AM             ARM
# 10                            Aruba         19            AW             ABW
# 11                        Australia      20531            AU             AUS
# 12                          Austria      32116            AT             AUT
# 13                       Azerbaijan      27741            AZ             AZE
# 14                          Bahamas        859            BS             BHS
# 15                     Bahamas, The         10             BS            BHS
# 16                          Bahrain      40346            BH             BHR
# 17                       Bangladesh     221685            BD             BGD
# 18                         Barbados        178            BB             BRB
# 19                          Belarus      77306            BV             BLR
# 20                          Belgium     100251            BE             BEL
# 21                           Belize        317            BZ             BLZ
# 22                            Benin       1609            BJ             BEN
# 23                           Bhutan        125            BT             BTN
# 24                          Bolivia      70107            BO             BOL
# 25           Bosnia and Herzegovina      11969            BA             BIH
# 26                         Botswana        798            BW             BWA
# 27                           Brazil    4342011            BR             BRA
# 28                           Brunei        248            BN             BRN
# 29                         Bulgaria      11058            BG             BGR
# ..                              ...        ...            ...            ...
# 193                          Sweden      89109            SE             SWE
# 194                     Switzerland      55579            CH             CHE
# 195                           Syria       3151            SY             SYR
# 196                          Taiwan       7833            TW             TWN
# 197                      Tajikistan      76741            TJ             TJK
# 198                        Tanzania       7325            TZ             TZA
# 199                        Thailand       5255            TH             THA
# 200                     The Bahamas          3             BS            BHS
# 201                      The Gambia          1             GM            GMB
# 202                     Timor-Leste       3694            TL             TLS
# 203                            Togo      10501            TG             TGO
# 204             Trinidad and Tobago      65610            TT             TTO
# 205                         Tunisia     266536            TN             TUN
# 206                          Turkey     299343            TR             TUR
# 207                              UK     427535            UK             GBR
# 208                              US    5836340             US            USA
# 209                          Uganda      16135            UG             UGA
# 210                         Ukraine      81314            UA             UKR
# 211            United Arab Emirates      68020            AE             ARE
# 212                         Uruguay      16413            UY             URY
# 213                      Uzbekistan      23662            UZ             UZB
# 214                    Vatican City          4            VA             VAT
# 215                       Venezuela      61518            VE             VEN
# 216                         Vietnam      83362             VT            VNM
# 217              West Bank and Gaza      11175            PS             WLF
# 218                  Western Sahara       1371            EH             ESH
# 219                           Yemen     155530            YE             YEM
# 220                          Zambia      18650            ZM             ZMB
# 221                        Zimbabwe      31098            ZW             ZWE
# 222  occupied Palestinian territory         25            PS             PSE
#
# [223 rows x 4 columns]

# %%
# Country/Region contain all world Countries 
# Confirmed contain all confirmed covid-19 cases 
# Country Abbr 2 contain every country with the abbreviation of 2 letter
# Country Abbr 3 contain every country with the abbreviation of 3 letter
# this 2 columns are useful to use Choropleth with plotly to make the world map
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Country Abbr 2', 'Country Abbr 3'], dtype='object')

# %%
# check for null Values
df.isnull().sum()
# Out:
# Country/Region    0
# Confirmed         0
# Country Abbr 2    0
# Country Abbr 3    0
# dtype: int64

# %%
plt.scatter(df['Confirmed'].iloc[:10],df['Country/Region'].iloc[:10],color='r')

# %%
fig = plt.figure(figsize=(7,16))
fig = plt.plot(df['Confirmed'].loc[:50],df['Country/Region'].loc[:50],color='green',lw = 2,ls='--',marker= 'o',markerfacecolor='red')
fig

# %%
# if you want to search for a specific country 
df.loc[df['Country/Region'] == 'France']
# Out:
#    Country/Region  Confirmed Country Abbr 2 Country Abbr 3
# 70         France     347615            FR             FRA

# %%
data_ = dict(type ='choropleth',locations =df['Country Abbr 3'],z = df['Confirmed'],
        colorbar = {'title': 'Covid-19 Spreading'})
layout = dict(title = 'Covid-19 World Spreading Analysis', geo = dict(showframe = False))
chronomap = go.Figure(data=[data_], layout=layout)

# %%
plot(chronomap)
# Out:
# 'temp-plot.html'
